# %% [markdown]
# # 🧹 TravelMate AI — Final Project Cleanup
#
# Run this notebook from the project environment to create the final packaging files:`requirements.txt`, `.gitignore`, `.env.example`, `README.md`, `DEPLOYMENT_CHECKLIST.md` and helper scripts.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd()
print(f"Project root: {PROJECT_ROOT}")

required_dirs = ["app", "src", "data", "notebooks"]
missing_dirs = [d for d in required_dirs if not (PROJECT_ROOT / d).exists()]
if missing_dirs:
    print("⚠️ Missing expected directories:", missing_dirs)
    print("Run this notebook from your TravelMate-AI project root.")
else:
    print("✅ Project root looks correct.")

# %%
# Paste the file-writing cell from the generated cleanup bundle if you want
# to recreate the files programmatically in your own project root.
# The ready-to-copy files are included alongside this notebook.
print("✅ Cleanup template prepared in the accompanying bundle.")

# %% [markdown]
# ## Final commands
#
# ```powershell
# pip install -r requirements.txt
# uvicorn app.main:app --reload
# streamlit run app/streamlit_app.py
# ```
#
# Then run the final system test notebook and manually smoke-test multiple cities.
